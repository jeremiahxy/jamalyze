# %%
### BEGIN SOLUTION
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

from sqlalchemy import func
from sqlalchemy import create_engine, inspect

# %%
engine = create_engine("sqlite:///EventsDB.db")

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['Events']

# %%
Events = Base.classes.Events

# %%
session = Session(engine)

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['Events']

# %%
columns = inspector.get_columns('Events')
for column in columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# genre VARCHAR(255)
# Latitude FLOAT
# Longitude FLOAT
# Name VARCHAR(255)
# PriceMaximum FLOAT
# PriceMinimum FLOAT
# StartDate VARCHAR(255)
# Subgenre VARCHAR(255)
# Venue VARCHAR(255)
# VenueID VARCHAR(255)

# %%
results = session.query(Events.genre).all()

print(results)
# Out:
# [('Pop',), ('Heavy Metal',), ('Pop',), ('Pop',), ('Pop',), ('Alternative Rock',), ('Pop',), ('Alternative Rock',), ('Alternative Rock',), ('Alternative Rock',), ('Pop',), ('Pop',), ('Alternative Rock',), ('Pop',), ('Alternative Rock',), ('Pop',), ('Pop',), ('Heavy Metal',), ('Heavy Metal',), ('Pop',), ('Pop',), ('Pop',), ('Adult Contemporary',), ('Heavy Metal',), ('Heavy Metal',), ('Heavy Metal',), ('Urban',), ('Urban',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Country',), ('Country',), ('Country',), ('Country',), ('Country',), ('Country',), ('Country',), ('Country',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Heavy Metal',), ('Country',), ('Country',), ('Country',), ('Country',), ('Pop',), ('Pop',), ('Country',), ('Pop',), ('Pop',), ('Country',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Country',), ('Pop',), ('Pop',), ('Country',), ('Country',), ('Country',), ('Country',), ('Country',), ('Pop',), ('Country',), ('Pop',), ('Pop',), ('Country',), ('Country',), ('Country',), ('Country',), ('Country',), ('Pop',), ('Country',), ('Pop',), ('Pop',), ('Adult Contemporary',), ('Country',), ('Country',), ('Country',), ('Country',), ('Country',), ('Adult Contemporary',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Country',), ('Country',), ('Country',), ('Country',), ('Urban',), ('Pop',), ('Pop',), ('Pop',), ('Urban',), ('Country',), ('Heavy Metal',), ('Adult Contemporary',), ('Adult Contemporary',), ('Adult Contemporary',), ('Adult Contemporary',), ('Adult Contemporary',), ('Pop',), ('Country',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Alternative Rock',), ('Alternative Rock',), ('Country',), ('Pop',), ('Alternative Rock',), ('Pop',), ('Pop',), ('Club Dance',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Country',), ('Alternative Rock',), ('Country',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Country',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Country',), ('Pop',), ('Club Dance',), ('Heavy Metal',), ('Heavy Metal',), ('Heavy Metal',), ('Country',), ('Heavy Metal',), ('Country',), ('Pop',), ('Alternative Rock',), ('Urban',), ('Country',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Alternative Rock',), ('Pop',), ('Country',), ('Pop',), ('Pop',), ('Urban',), ('Pop',), ('Urban',), ('Urban',), ('Urban',), ('Urban',), ('Urban',), ('Urban',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Country',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Country',), ('Country',), ('Adult Contemporary',), ('Urban',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Alternative Rock',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Country',), ('Country',), ('Country',), ('Country',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Urban',), ('Urban',), ('Urban',), ('Urban',), ('Urban',), ('Urban',), ('Urban',), ('Urban',), ('Heavy Metal',), ('Heavy Metal',), ('Urban',), ('Country',), ('Country',), ('Pop',), ('Pop',), ('Pop',), ('Heavy Metal',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Country',), ('Country',), ('Urban',), ('Pop',), ('Country',), ('Pop',), ('Heavy Metal',), ('Heavy Metal',), ('Heavy Metal',), ('Heavy Metal',), ('Country',), ('Heavy Metal',), ('Heavy Metal',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Pop',), ('Country',), ('Country',), ('Country',), ('Pop',), ('Pop',), ('Pop',), ('Pop ...

# %%
results = session.query(Events.genre).distinct().all()
print(results)
# Out:
# [('Rock',), ('Metal',), ('Pop',), ('Hip-Hop/Rap',), ('Country',), ('Dance/Electronic',), ('Alternative',)]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-148fa23b6411> in <module>()
#       1 assurances = []
# ----> 2 for rows in session.query.distinct(Events.Subgenre):
#       3     assurances.append(Events.Subgenre)
#
# AttributeError: 'function' object has no attribute 'distinct'
